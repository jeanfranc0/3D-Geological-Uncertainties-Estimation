# %%
import os
import sys
import time
import copy
import argparse
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import plotly.express as px

from tensorflow.keras import Input, Model
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import StandardScaler, QuantileTransformer, MaxAbsScaler, MinMaxScaler, RobustScaler, normalize

from SALib.sample import sobol
from SALib.analyze import sobol as sobol_analyze

from models.ann3D import ANN
from models.cnn3D import CNN3D
from models.cblstm3D import MEDA
from src.notebook_util import setup_gpu
from src.visualization import visualizationResults, plot_learning_curves, computeAndSaveSmapeAndNQDS
from utils import loadNpFile, load_pkl_file, clear_and_save, loadTXTFile
from src.data_loader import loadUncertainties, loadProductionANDHistory, selectProductionCurve
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def sobolSampler(X_test):
    # Define your input parameters and their ranges
    problem = {
        'num_vars': X_test.shape[1],
        'bounds': [[np.min(X_test[:, i]), np.max(X_test[:, i])] for i in range(X_test.shape[1])]
    }

    # Generate the samples using the Saltelli sampling scheme
    X_test_sobol = sobol.sample(problem, 1024, calc_second_order=False)
    return X_test_sobol, problem

# %%
from tensorflow.keras.callbacks import EarlyStopping

def select_model(ann_chosen, input_shapes, n_outputs):
    # Select the model based on the user's choice.  
    if ann_chosen == 'ANN':
        model = ANN(*input_shapes, n_outputs).model
    elif ann_chosen == 'proxy':
        model = CNN3D(*input_shapes, n_outputs).model
    elif ann_chosen == 'meda':
        model = MEDA(*input_shapes, n_outputs).model
    return model

def configure_callbacks():
    # Configures and returns a list of callbacks for training.
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=40, verbose=1, mode='auto')
    return [earlystop]

def reshape_uncertainties(uncertainties):
    # Redimensiona incertezas de fluidos para adicionar uma dimensão
    return uncertainties.reshape(uncertainties.shape[0], uncertainties.shape[1], 1)

def train_evaluate_model(x_train, x_val, x_test, y_train, y_val, y_test, ann_chosen, data_augmentation=False):
    n_outputs = y_train.shape[1]
    input_shapes = [(x.shape[1], x.shape[2], x.shape[3], x.shape[4]) for x in x_train[:4]] + [(x_train[4].shape[1], 1)]
    
    model = select_model(ann_chosen, input_shapes, n_outputs)
    
    callbacks_list = configure_callbacks()
        
    history = model.fit(x=x_train, 
                        y=y_train, 
                        batch_size=8, 
                        epochs=200, 
                        shuffle=True, 
                        callbacks=callbacks_list, 
                        verbose=2, 
                        validation_data=(x_val, y_val))

    metrics = model.evaluate(x_test, y_test, verbose=1, batch_size=1)

    plot_learning_curves(history.history['loss'], history.history['val_loss'])
    
    return metrics[1:], model  

def extract_layer_output(model, layer_index=-4):
    # Extracts output from a specific layer of the model.
    layer_output = model.layers[layer_index].output
    return Model(inputs=model.input, outputs=layer_output)

def predict_with_model(model, inputs):
    # Makes predictions using the model for a set of inputs.
    return model.predict(x=inputs)

# %%
def reconstruct_model_for_new_input(cnn_model, new_input_shape, start_layer=-3):
    # """
    # Rebuilds an existing model to accept a new input shape,
    # reconnecting the layers from a specific point.
    # """
    new_input = Input(shape=new_input_shape)
    x = new_input
    for layer in cnn_model.layers[start_layer:]:
        x = layer(x)
    new_model = Model(inputs=new_input, outputs=x)
    return new_model

# %%
import copy
import numpy as np
from scipy.stats import linregress
from sklearn.metrics import r2_score
from src.metrics import smape
from sklearn.preprocessing import MinMaxScaler

def preprocess_targets(targets):
    # Preprocesses the targets by removing and combining specific columns.
    processed_targets = targets[:28] + targets[56:63]
    processed_targets = np.delete(processed_targets, np.s_[14:21])
    return processed_targets

def load_or_process_targets(path, targets):
    # Loads the targets from files if a path is provided; otherwise, processes them.
    if path:
        return np.concatenate([loadNpFile(path, target) for target in targets], axis=1)
    
    return targets

def save_original_targets(y_train, y_test, y_val):
    # Saves the original targets by creating deep copies of the input target arrays.
    y_train = copy.deepcopy(y_train)
    y_test  = copy.deepcopy(y_test) 
    y_val   = copy.deepcopy(y_val)
    return y_train, y_test, y_val

def normalize_targets(y_train, y_test, y_val, normalize=False):
    # Normalizes the targets if necessary.
    if normalize:
        scaler = MinMaxScaler()
        y_train =  scaler.fit_transform(y_train)
        y_test =  scaler.transform(y_test)
        y_val =  scaler.transform(y_val)
    return y_train, y_test, y_val, scaler

def resize_uncertainty(uncertainty):
    # Resizes the uncertainty by adding rows at the top and bottom and reducing one column.
    new_height = uncertainty.shape[2] + 10  # Adding 5 rows at the top and 5 rows at the bottom
    new_width = uncertainty.shape[3] - 1    # Reducing 1 column in the width dimension
    duplicated_array = np.zeros((uncertainty.shape[0], uncertainty.shape[1], new_height, uncertainty.shape[3], uncertainty.shape[4]))
    duplicated_array[:, :, 5:-5, :, :] = uncertainty
    saved_column = duplicated_array[:, :, :, 0:1, :]
    final_array = duplicated_array[:, :, :, :new_width, :]
    return final_array, saved_column

def apply_resize_uncertainties(x_data):
    # Application of the resizing function to all input data
    resized_data = []
    saved_columns = []
    for data in x_data:
        resized, saved_column = resize_uncertainty(data)
        resized_data.append(resized)
        saved_columns.append(saved_column)
    return resized_data, saved_columns

def compute_inverse_normalization(normalizer, y_val_p, y_test_p):
    y_val_p = normalizer.inverse_transform(y_val_p)
    y_test_p = normalizer.inverse_transform(y_test_p)
    return y_val_p, y_test_p

def metrics(ytrue, ypred, start, end):
    smp = smape(ytrue[:, start:end].flatten(), ypred[:, start:end].flatten())
    _,_,correlation,_,_ = linregress(ytrue[:, start:end].flatten(), ypred[:, start:end].flatten())
    r2 = r2_score(ytrue[:, start:end].flatten(), ypred[:, start:end].flatten())
    return round(smp, 3), round(correlation, 3), round(r2, 3)

def apply_metrics(ytrue, ypred, data_split):
    production_dict = {'oil':   [0, 35],
                       'water': [35, 70],
                       'gas':   [70, 105],
                       'bhp':   [105, 140]}
    print('*******'+data_split+'*******')
    for production, days in production_dict.items():
        product_smape, product_correlation, product_r2 = metrics(ytrue, ypred, days[0], days[1])
        print('*****'+production+'*****')
        print('smape:', product_smape)
        print('correlation:', product_correlation)
        print('r2', product_r2)

# %%
def train_model(x_train_por_3d, x_train_rtp_3d, x_train_ntg_3d, 
                x_train_permi_3d, x_train_fluid_uncertainties, x_test_por_3d, 
                x_test_rtp_3d, x_test_ntg_3d, x_test_permi_3d, 
                x_test_fluid_uncertainties, x_val_por_3d, x_val_rtp_3d, 
                x_val_ntg_3d, x_val_permi_3d, x_val_fluid_uncertainties, 
                y_train, y_test, y_val, ann,
                path_to_production=None, production_path=None, 
                history_path=None, days_txt=None,
                results_path=None, is_some_days=None, history_data=None,
                normalized_output=False, optimize_analysis=False):
    
    # Preprocessing of the targets
    y_train = preprocess_targets(y_train)
    y_test = preprocess_targets(y_test)
    y_val = preprocess_targets(y_val)

    # Loading or processing of the targets
    y_train = load_or_process_targets(path_to_production, y_train)
    y_test = load_or_process_targets(path_to_production, y_test)
    y_val = load_or_process_targets(path_to_production, y_val)
    
    # Maintain the original targets before normalization
    y_train_gt, y_test_gt, y_val_gt = save_original_targets(y_train, y_test, y_val)
    
    # Normalization of the targets, if necessary
    y_train, y_test, y_val, scaler = normalize_targets(y_train, y_test, y_val, normalized_output)
 
    # Resizing for training, validation, and test sets
    x_train, saved_columns_train = apply_resize_uncertainties([x_train_por_3d, x_train_rtp_3d, x_train_ntg_3d, x_train_permi_3d])
    x_val, saved_columns_val = apply_resize_uncertainties([x_val_por_3d, x_val_rtp_3d, x_val_ntg_3d, x_val_permi_3d])
    x_test, saved_columns_test = apply_resize_uncertainties([x_test_por_3d, x_test_rtp_3d, x_test_ntg_3d, x_test_permi_3d])
    
    x_train_fluid_uncertainties = reshape_uncertainties(x_train_fluid_uncertainties)
    x_val_fluid_uncertainties = reshape_uncertainties(x_val_fluid_uncertainties)
    x_test_fluid_uncertainties = reshape_uncertainties(x_test_fluid_uncertainties)
    
    x_train.append(x_train_fluid_uncertainties)
    x_val.append(x_val_fluid_uncertainties)
    x_test.append(x_test_fluid_uncertainties)
    
    # create the model
    metrics, model = train_evaluate_model(x_train, x_val, x_test, y_train, y_val, y_test, ann, data_augmentation=False)
    
    # get the prediction on the test and validation sets
    y_val_pred = model.predict(x=x_val)
    y_test_pred = model.predict(x=x_test)
    
    y_val_pred, y_test_pred = compute_inverse_normalization(scaler, y_val_pred, y_test_pred)
    
    apply_metrics(y_test_gt, y_test_pred, data_split='Test')
    apply_metrics(y_val_gt, y_val_pred, data_split='Validation')
    
    # production curves visualization 
    averageTest, averageValidation = computeAndSaveSmapeAndNQDS(
        production_path,
        history_path,
        days_txt,
        y_test_gt, y_test_pred,
        y_val_gt, y_val_pred,
        results_path,
        is_some_days, 
        history_data
    )
    
    new_model = extract_layer_output(model, layer_index=-4)
    x_test_encoder = predict_with_model(new_model, x_test)
    print(x_test_encoder.shape)
    
    if path_to_production and optimize_analysis:
        
        print('Sensitivity Analysis - Sampler')
        # Scala as características para o SOBOL não sofrer interferencia das escalas
        x_test_encoder = MinMaxScaler().fit_transform(x_test_encoder)
        X_test_sobol, problem = sobolSampler(x_test_encoder)
        print(X_test_sobol.shape)
        print(f'Metrics: {metrics}')
        
        new_model = reconstruct_model_for_new_input(model, new_input_shape=(1094,), start_layer=-3)

        
        y_test_sobol = new_model.predict(x = X_test_sobol)
        y_test_sobol = scaler.inverse_transform(y_test_sobol)

        return problem, y_test_sobol, x_test_encoder, new_model

# %%
import time

def setup_gpu_environment(gpu_id):
    # "Configures the GPU environment."
    setup_gpu(gpu_id)

def load_data(uncertainties_path, production_path, history_path, is_some_days):
    """
    Loads uncertainty, production, and historical datasets, considering the configuration of specific days.
    
    Args:
        uncertainties_path (str): Path to the uncertainty data.
        production_path (str): Base path for the production data.
        history_path (str): Base path for the historical data.
        is_some_days (str): Suffix for the paths, indicating whether they are data for specific days.
    
    Returns:
        Tuple: Loaded training, testing, validation, and historical datasets.
    """
    production_path_with_days = f"{production_path}{is_some_days}/"
    history_path_with_days = f"{history_path}{is_some_days}/"

    # Load uncertainties
    x_train_porosity_3d, x_train_rtp_3d, x_train_ntg_3d, x_train_permi_3d, x_train_fluid_uncertainties, \
    x_test_porosity_3d, x_test_rtp_3d, x_test_ntg_3d, x_test_permi_3d, x_test_fluid_uncertainties, \
    x_val_porosity_3d, x_val_rtp_3d, x_val_ntg_3d, x_val_permi_3d, x_val_fluid_uncertainties = loadUncertainties(uncertainties_path)

    # Load production data
    train_output = loadProductionANDHistory(production_path_with_days, String="Production", typeOfSet="train")
    test_output = loadProductionANDHistory(production_path_with_days, String="Production", typeOfSet="test")
    val_output = loadProductionANDHistory(production_path_with_days, String="Production", typeOfSet="validation")
    
    # Load historical data
    history_data = loadProductionANDHistory(history_path_with_days, String="History")

    return (
        (x_train_porosity_3d, x_train_rtp_3d, x_train_ntg_3d, x_train_permi_3d, x_train_fluid_uncertainties),
        (x_test_porosity_3d, x_test_rtp_3d, x_test_ntg_3d, x_test_permi_3d, x_test_fluid_uncertainties),
        (x_val_porosity_3d, x_val_rtp_3d, x_val_ntg_3d, x_val_permi_3d, x_val_fluid_uncertainties),
        train_output, test_output, val_output, history_data
    )

def pretrained(uncertainties_path, production_path, history_path, days_txt, gpu_id,
        is_some_days, results_path, ann, optimize_analysis):
    """
    Train the model end-to-end with uncertainty, production, and historical data.

    Args:
        uncertainties_path (str): Path to the uncertainty data.
        upload_production_path (str): Path for uploading production data.
        save_history_path (str): Path for saving historical data.
        some_days_txt (str): Suffix for paths indicating specific days.
        gpu (int): GPU configuration.
        is_some_days (str): Suffix for paths indicating specific days.
        results_path (str): Path for saving results.
        start_to_train (float): Start training configuration.
        opt_analysis (bool): Whether optimization analysis should be performed.

    Returns:
        Tuple: Results of the trained model including problem, y_test_sobol, x_test_encoder, new_model.
    """

    setup_gpu_environment(gpu_id)

    x_train, x_test, x_val, train_output, test_output, val_output, history_data = load_data(
        uncertainties_path, production_path, history_path, is_some_days
    )
    
    problem, y_test_sobol, x_test_encoder, new_model = train_model(
        *x_train, *x_test, *x_val,
        train_output, test_output, val_output,
        path_to_production=f"{production_path}{is_some_days}/",
        production_path=production_path, history_path=history_path, 
        days_txt=days_txt, results_path=results_path, 
        is_some_days=is_some_days, history_data=history_data[0],
        normalized_output=True,
        optimize_analysis=optimize_analysis,
        ann = ann
    )

    return problem, y_test_sobol, x_test_encoder, new_model

# %%
# Example of how to call the fit function
if __name__ == "__main__":
    uncertainties_path = '/tf/notebooks/jeanfranco/end-to-end/normalization/Uncertainties/'
    production_path = '/tf/notebooks/jeanfranco/end-to-end/normalization/ObjectiveFunction/'
    history_path = '/tf/notebooks/jeanfranco/end-to-end/normalization/Observed/'
    days_txt = '/tf/notebooks/jeanfranco/end-to-end/days.txt'
    gpu_id = 0
    is_some_days = 'someDays'
    results_path = '/tf/notebooks/jeanfranco/end-to-end/Notebooks/3DCNNSave/'
    
    problem, y_test_sobol, x_test_encoder, new_model = pretrained(
        uncertainties_path=uncertainties_path,
        production_path=production_path,
        history_path=history_path,
        days_txt=days_txt,
        gpu_id=gpu_id,
        is_some_days=is_some_days,
        results_path=results_path,
        ann='proxy',
        optimize_analysis=True
    )
# Out:
# init
# build model
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/normalization/batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Por3D_input (InputLayer)       [(None, 24, 48, 72,  0           []
#                                  1)]
#
#  Rtp3D_input (InputLayer)       [(None, 24, 48, 72,  0           []
#                                  1)]
#
#  Ntg3D_input (InputLayer)       [(None, 24, 48, 72,  0           []
#                                  1)]
#
#  Permi3D_input (InputLayer)     [(None, 24, 48, 72,  0           []
#                                  1)]
#
#  conv3d (Conv3D)                (None, 12, 24, 36,   448         ['Por3D_input[0][0]']
#                                 16)
#
#  conv3d_8 (Conv3D)              (None, 12, 24, 36,   448         ['Rtp3D_input[0][0]']
#                                 16)
#
#  conv3d_16 (Conv3D)             (None, 12, 24, 36,   448         ['Ntg3D_input[0][0]']
#                                 16)
#
#  conv3d_24 (Conv3D)             (None, 12, 24, 36,   448         ['Permi3D_input[0][0]']
#                                 16)
#
#  batch_normalization (BatchNorm  (None, 12, 24, 36,   64         ['conv3d[0][0]']
#  alization)                     16)
#
#  batch_normalization_8 (BatchNo  (None, 12, 24, 36,   64         ['conv3d_8[0][0]']
#  rmalization)                   16)
#
#  batch_normalization_16 (BatchN  (None, 12, 24, 36,   64         ['conv3d_16[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_24 (BatchN  (None, 12, 24, 36,   64         ['conv3d_24[0][0]']
#  ormalization)                  16)
#
#  activation (Activation)        (None, 12, 24, 36,   0           ['batch_normalization[0][0]']
#                                 16)
#
#  activation_6 (Activation)      (None, 12, 24, 36,   0           ['batch_normalization_8[0][0]']
#                                 16)
#
#  activation_12 (Activation)     (None, 12, 24, 36,   0           ['batch_normalization_16[0][0]']
#                                 16)
#
#  activation_18 (Activation)     (None, 12, 24, 36,   0           ['batch_normalization_24[0][0]']
#                                 16)
#
#  dropout (Dropout)              (None, 12, 24, 36,   0           ['activation[0][0]']
#                                 16)
#
#  dropout_5 (Dropout)            (None, 12, 24, 36,   0           ['activation_6[0][0]']
#                                 16)
#
#  dropout_10 (Dropout)           (None, 12, 24, 36,   0           ['activation_12[0][0]']
#                                 16)
#
#  dropout_15 (Dropout)           (None, 12, 24, 36,   0           ['activation_18[0][0]']
#                                 16)
#
#  conv3d_1 (Conv3D)              (None, 12, 24, 36,   6928        ['dropout[0][0]']
#                                 16)
#
#  conv3d_9 (Conv3D)              (None, 12, 24, 36,   6928        ['dropout_5[0][0]']
#                                 16)
#
#  conv3d_17 (Conv3D)             (None, 12, 24, 36,   6928        ['dropout_10[0][0]']
#                                 16)
#
#  conv3d_25 (Conv3D)             (None, 12, 24, 36,   6928        ['dropout_15[0][0]']
#                                 16)
#
#  batch_normalization_1 (BatchNo  (None, 12, 24, 36,   64         ['conv3d_1[0][0]']
#  rmalization)                   16)
#
#  batch_normalization_9 (BatchNo  (None, 12, 24, 36,   64         ['conv3d_9[0][0]']
#  rmalization)                   16)
#
#  batch_normalization_17 (BatchN  (None, 12, 24, 36,   64         ['conv3d_17[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_25 (BatchN  (None, 12, 24, 36,   64         ['conv3d_25[0][0]']
#  ormalization)                  16)
#
#  activation_1 (Activation)      (None, 12, 24, 36,   0           ['batch_normalization_1[0][0]']
#                                 16)
#
#  activation_7 (Activation)      (None, 12, 24, 36,   0           ['batch_normalization_9[0][0]']
#                                 16)
#
#  activation_13 (Activation)     (None, 12, 24, 36,   0           ['batch_normalization_17[0][0]']
#                                 16)
#
#  activation_19 (Activation)     (None, 12, 24, 36,   0           ['batch_normalization_25[0][0]']
#                                 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 4, 8, 12, 16  0           ['activation_1[0][0]']
#                                 )
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 4, 8, 12, 16  0          ['activation_7[0][0]']
#                                 )
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 4, 8, 12, 16  0          ['activation_13[0][0]']
#                                 )
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 4, 8, 12, 16  0          ['activation_19[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 4, 8, 12, 16  0           ['max_pooling3d[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 4, 8, 12, 16  0           ['max_pooling3d_2[0][0]']
#                                 )
#
#  dropout_11 (Dropout)           (None, 4, 8, 12, 16  0           ['max_pooling3d_4[0][0]']
#                                 )
#
#  dropout_16 (Dropout)           (None, 4, 8, 12, 16  0           ['max_pooling3d_6[0][0]']
#                                 )
#
#  conv3d_2 (Conv3D)              (None, 4, 8, 12, 32  13856       ['dropout_1[0][0]']
#                                 )
#
#  conv3d_10 (Conv3D)             (None, 4, 8, 12, 32  13856       ['dropout_6[0][0]']
#                                 )
#
#  conv3d_18 (Conv3D)             (None, 4, 8, 12, 32  13856       ['dropout_11[0][0]']
#                                 )
#
#  conv3d_26 (Conv3D)             (None, 4, 8, 12, 32  13856       ['dropout_16[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 4, 8, 12, 32  128        ['conv3d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_10 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_10[0][0]']
#  ormalization)                  )
#
#  batch_normalization_18 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_18[0][0]']
#  ormalization)                  )
#
#  batch_normalization_26 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_26[0][0]']
#  ormalization)                  )
#
#  activation_2 (Activation)      (None, 4, 8, 12, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 4, 8, 12, 32  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  activation_14 (Activation)     (None, 4, 8, 12, 32  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  activation_20 (Activation)     (None, 4, 8, 12, 32  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 4, 8, 12, 32  0           ['activation_2[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 4, 8, 12, 32  0           ['activation_8[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 4, 8, 12, 32  0           ['activation_14[0][0]']
#                                 )
#
#  dropout_17 (Dropout)           (None, 4, 8, 12, 32  0           ['activation_20[0][0]']
#                                 )
#
#  conv3d_3 (Conv3D)              (None, 4, 8, 12, 32  27680       ['dropout_2[0][0]']
#                                 )
#
#  conv3d_11 (Conv3D)             (None, 4, 8, 12, 32  27680       ['dropout_7[0][0]']
#                                 )
#
#  conv3d_19 (Conv3D)             (None, 4, 8, 12, 32  27680       ['dropout_12[0][0]']
#                                 )
#
#  conv3d_27 (Conv3D)             (None, 4, 8, 12, 32  27680       ['dropout_17[0][0]']
#                                 )
#
#  conv3d_4 (Conv3D)              (None, 4, 8, 12, 32  27680       ['conv3d_3[0][0]']
#                                 )
#
#  conv3d_12 (Conv3D)             (None, 4, 8, 12, 32  27680       ['conv3d_11[0][0]']
#                                 )
#
#  conv3d_20 (Conv3D)             (None, 4, 8, 12, 32  27680       ['conv3d_19[0][0]']
#                                 )
#
#  conv3d_28 (Conv3D)             (None, 4, 8, 12, 32  27680       ['conv3d_27[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 4, 8, 12, 32  128        ['conv3d_4[0][0]']
#  rmalization)                   )
#
#  batch_normalization_12 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_12[0][0]']
#  ormalization)                  )
#
#  batch_normalization_20 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_20[0][0]']
#  ormalization)                  )
#
#  batch_normalization_28 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_28[0][0]']
#  ormalization)                  )
#
#  re_lu (ReLU)                   (None, 4, 8, 12, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  re_lu_2 (ReLU)                 (None, 4, 8, 12, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  re_lu_4 (ReLU)                 (None, 4, 8, 12, 32  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  re_lu_6 (ReLU)                 (None, 4, 8, 12, 32  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv3d_5 (Conv3D)              (None, 4, 8, 12, 32  27680       ['re_lu[0][0]']
#                                 )
#
#  conv3d_13 (Conv3D)             (None, 4, 8, 12, 32  27680       ['re_lu_2[0][0]']
#                                 )
#
#  conv3d_21 (Conv3D)             (None, 4, 8, 12, 32  27680       ['re_lu_4[0][0]']
#                                 )
#
#  conv3d_29 (Conv3D)             (None, 4, 8, 12, 32  27680       ['re_lu_6[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 4, 8, 12, 32  128        ['conv3d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_13 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_13[0][0]']
#  ormalization)                  )
#
#  batch_normalization_21 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_21[0][0]']
#  ormalization)                  )
#
#  batch_normalization_29 (BatchN  (None, 4, 8, 12, 32  128        ['conv3d_29[0][0]']
#  ormalization)                  )
#
#  add (Add)                      (None, 4, 8, 12, 32  0           ['conv3d_3[0][0]',
#                                 )                                 'batch_normalization_5[0][0]']
#
#  add_1 (Add)                    (None, 4, 8, 12, 32  0           ['conv3d_11[0][0]',
#                                 )                                 'batch_normalization_13[0][0]']
#
#  add_2 (Add)                    (None, 4, 8, 12, 32  0           ['conv3d_19[0][0]',
#                                 )                                 'batch_normalization_21[0][0]']
#
#  add_3 (Add)                    (None, 4, 8, 12, 32  0           ['conv3d_27[0][0]',
#                                 )                                 'batch_normalization_29[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 4, 8, 12, 32  0           ['add[0][0]']
#                                 )
#
#  re_lu_3 (ReLU)                 (None, 4, 8, 12, 32  0           ['add_1[0][0]']
#                                 )
#
#  re_lu_5 (ReLU)                 (None, 4, 8, 12, 32  0           ['add_2[0][0]']
#                                 )
#
#  re_lu_7 (ReLU)                 (None, 4, 8, 12, 32  0           ['add_3[0][0]']
#                                 )
#
#  conv3d_6 (Conv3D)              (None, 2, 4, 6, 64)  55360       ['re_lu_1[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 2, 4, 6, 64)  55360       ['re_lu_3[0][0]']
#
#  conv3d_22 (Conv3D)             (None, 2, 4, 6, 64)  55360       ['re_lu_5[0][0]']
#
#  conv3d_30 (Conv3D)             (None, 2, 4, 6, 64)  55360       ['re_lu_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 2, 4, 6, 64)  256        ['conv3d_6[0][0]']
#  rmalization)
#
#  batch_normalization_14 (BatchN  (None, 2, 4, 6, 64)  256        ['conv3d_14[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 2, 4, 6, 64)  256        ['conv3d_22[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 2, 4, 6, 64)  256        ['conv3d_30[0][0]']
#  ormalization)
#
#  activation_4 (Activation)      (None, 2, 4, 6, 64)  0           ['batch_normalization_6[0][0]']
#
#  activation_10 (Activation)     (None, 2, 4, 6, 64)  0           ['batch_normalization_14[0][0]']
#
#  activation_16 (Activation)     (None, 2, 4, 6, 64)  0           ['batch_normalization_22[0][0]']
#
#  activation_22 (Activation)     (None, 2, 4, 6, 64)  0           ['batch_normalization_30[0][0]']
#
#  dropout_3 (Dropout)            (None, 2, 4, 6, 64)  0           ['activation_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 2, 4, 6, 64)  0           ['activation_10[0][0]']
#
#  dropout_13 (Dropout)           (None, 2, 4, 6, 64)  0           ['activation_16[0][0]']
#
#  dropout_18 (Dropout)           (None, 2, 4, 6, 64)  0           ['activation_22[0][0]']
#
#  conv3d_7 (Conv3D)              (None, 2, 4, 6, 64)  110656      ['dropout_3[0][0]']
#
#  conv3d_15 (Conv3D)             (None, 2, 4, 6, 64)  110656      ['dropout_8[0][0]']
#
#  conv3d_23 (Conv3D)             (None, 2, 4, 6, 64)  110656      ['dropout_13[0][0]']
#
#  conv3d_31 (Conv3D)             (None, 2, 4, 6, 64)  110656      ['dropout_18[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 2, 4, 6, 64)  256        ['conv3d_7[0][0]']
#  rmalization)
#
#  batch_normalization_15 (BatchN  (None, 2, 4, 6, 64)  256        ['conv3d_15[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 2, 4, 6, 64)  256        ['conv3d_23[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 2, 4, 6, 64)  256        ['conv3d_31[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 2, 4, 6, 64)  0           ['batch_normalization_7[0][0]']
#
#  activation_11 (Activation)     (None, 2, 4, 6, 64)  0           ['batch_normalization_15[0][0]']
#
#  activation_17 (Activation)     (None, 2, 4, 6, 64)  0           ['batch_normalization_23[0][0]']
#
#  activation_23 (Activation)     (None, 2, 4, 6, 64)  0           ['batch_normalization_31[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 1, 2, 3, 64)  0          ['activation_5[0][0]']
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 1, 2, 3, 64)  0          ['activation_11[0][0]']
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 1, 2, 3, 64)  0          ['activation_17[0][0]']
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 1, 2, 3, 64)  0          ['activation_23[0][0]']
#
#  dropout_4 (Dropout)            (None, 1, 2, 3, 64)  0           ['max_pooling3d_1[0][0]']
#
#  dropout_9 (Dropout)            (None, 1, 2, 3, 64)  0           ['max_pooling3d_3[0][0]']
#
#  dropout_14 (Dropout)           (None, 1, 2, 3, 64)  0           ['max_pooling3d_5[0][0]']
#
#  dropout_19 (Dropout)           (None, 1, 2, 3, 64)  0           ['max_pooling3d_7[0][0]']
#
#  flatten (Flatten)              (None, 384)          0           ['dropout_4[0][0]']
#
#  flatten_1 (Flatten)            (None, 384)          0           ['dropout_9[0][0]']
#
#  flatten_2 (Flatten)            (None, 384)          0           ['dropout_14[0][0]']
#
#  flatten_3 (Flatten)            (None, 384)          0           ['dropout_19[0][0]']
#
#  fluidUncertainties_input (Inpu  [(None, 70, 1)]     0           []
#  tLayer)
#
#  dense (Dense)                  (None, 256)          98560       ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 256)          98560       ['flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          98560       ['flatten_2[0][0]']
#
#  dense_3 (Dense)                (None, 256)          98560       ['flatten_3[0][0]']
#
#  reshape (Reshape)              (None, 70)           0           ['fluidUncertainties_input[0][0]'
#                                                                  ]
#
#  concatenate (Concatenate)      (None, 1094)         0           ['dense[0][0]',
#                                                                   'dense_1[0][0]',
#                                                                   'dense_2[0][0]',
#                                                                   'dense_3[0][0]',
#                                                                   'reshape[0][0]']
#
#  dense_4 (Dense)                (None, 512)          560640      ['concatenate[0][0]']
#
#  dropout_20 (Dropout)           (None, 512)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 140)          71820       ['dropout_20[0][0]']
#
# ==================================================================================================
# Total params: 2,111,948
# Trainable params: 2,109,900
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# Train on 100 samples, validate on 40 samples
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 100/100 - 4s - loss: 1.8241 - mean_absolute_error: 3.5734 - rmse: 4.4719 - smape_loss: 1.5641 - r2: -2.2054e+02 - correlation: 0.0594 - val_loss: 1.2726 - val_mean_absolute_error: 0.7412 - val_rmse: 0.9265 - val_smape_loss: 1.1282 - val_r2: -8.3418e+00 - val_correlation: 0.1281 - 4s/epoch - 39ms/sample
# Epoch 2/200
# 100/100 - 1s - loss: 1.7120 - mean_absolute_error: 2.8660 - rmse: 3.5661 - smape_loss: 1.4746 - r2: -1.4199e+02 - correlation: 0.0993 - val_loss: 1.2435 - val_mean_absolute_error: 0.6520 - val_rmse: 0.8042 - val_smape_loss: 1.0976 - val_r2: -6.0861e+00 - val_correlation: 0.0601 - 1s/epoch - 11ms/sample
# Epoch 3/200
# 100/100 - 1s - loss: 1.5502 - mean_absolute_error: 1.7621 - rmse: 2.1957 - smape_loss: 1.3454 - r2: -5.2224e+01 - correlation: 0.0344 - val_loss: 1.1248 - val_mean_absolute_error: 0.5658 - val_rmse: 0.7181 - val_smape_loss: 0.9764 - val_r2: -4.7075e+00 - val_correlation: 0.0832 - 1s/epoch - 11ms/sample
# Epoch 4/200
# 100/100 - 1s - loss: 1.3990 - mean_absolute_error: 1.1763 - rmse: 1.4675 - smape_loss: 1.2034 - r2: -2.2830e+01 - correlation: 0.0723 - val_loss: 1.0258 - val_mean_absolute_error: 0.4304 - val_rmse: 0.5324 - val_smape_loss: 0.8732 - val_r2: -2.0987e+00 - val_correlation: 0.1627 - 1s/epoch - 12ms/sample
# Epoch 5/200
# 100/100 - 1s - loss: 1.2332 - mean_absolute_error: 0.7025 - rmse: 0.8931 - smape_loss: 1.0404 - r2: -7.7824e+00 - correlation: 0.1284 - val_loss: 0.9767 - val_mean_absolute_error: 0.4031 - val_rmse: 0.4948 - val_smape_loss: 0.8193 - val_r2: -1.6702e+00 - val_correlation: 0.2328 - 1s/epoch - 12ms/sample
# Epoch 6/200
# 100/100 - 1s - loss: 1.1626 - mean_absolute_error: 0.6098 - rmse: 0.7557 - smape_loss: 0.9698 - r2: -5.3513e+00 - correlation: 0.1296 - val_loss: 0.9681 - val_mean_absolute_error: 0.3881 - val_rmse: 0.4737 - val_smape_loss: 0.8130 - val_r2: -1.4680e+00 - val_correlation: 0.1676 - 1s/epoch - 11ms/sample
# Epoch 7/200
# 100/100 - 1s - loss: 1.1053 - mean_absolute_error: 0.5847 - rmse: 0.7304 - smape_loss: 0.9160 - r2: -5.0353e+00 - correlation: 0.1615 - val_loss: 0.8402 - val_mean_absolute_error: 0.3355 - val_rmse: 0.4159 - val_smape_loss: 0.6900 - val_r2: -8.9466e-01 - val_correlation: 0.3094 - 1s/epoch - 11ms/sample
# Epoch 8/200
# 100/100 - 1s - loss: 1.0487 - mean_absolute_error: 0.5494 - rmse: 0.6914 - smape_loss: 0.8667 - r2: -4.3275e+00 - correlation: 0.1987 - val_loss: 0.8411 - val_mean_absolute_error: 0.3405 - val_rmse: 0.4170 - val_smape_loss: 0.6931 - val_r2: -9.0137e-01 - val_correlation: 0.2875 - 1s/epoch - 11ms/sample
# Epoch 9/200
# 100/100 - 1s - loss: 0.9749 - mean_absolute_error: 0.4737 - rmse: 0.5892 - smape_loss: 0.7976 - r2: -2.8374e+00 - correlation: 0.2250 - val_loss: 0.6640 - val_mean_absolute_error: 0.2713 - val_rmse: 0.3409 - val_smape_loss: 0.5162 - val_r2: -2.6323e-01 - val_correlation: 0.4429 - 1s/epoch - 11ms/sample
# Epoch 10/200
# 100/100 - 1s - loss: 0.8861 - mean_absolute_error: 0.4264 - rmse: 0.5383 - smape_loss: 0.7111 - r2: -2.2422e+00 - correlation: 0.2615 - val_loss: 0.6207 - val_mean_absolute_error: 0.2547 - val_rmse: 0.3185 - val_smape_loss: 0.4733 - val_r2: -1.0853e-01 - val_correlation: 0.5237 - 1s/epoch - 12ms/sample
# Epoch 11/200
# 100/100 - 1s - loss: 0.8174 - mean_absolute_error: 0.3783 - rmse: 0.4883 - smape_loss: 0.6445 - r2: -1.6996e+00 - correlation: 0.3204 - val_loss: 0.6487 - val_mean_absolute_error: 0.2725 - val_rmse: 0.3351 - val_smape_loss: 0.5030 - val_r2: -2.2656e-01 - val_correlation: 0.5648 - 1s/epoch - 12ms/sample
# Epoch 12/200
# 100/100 - 1s - loss: 0.7082 - mean_absolute_error: 0.3380 - rmse: 0.4405 - smape_loss: 0.5366 - r2: -1.1678e+00 - correlation: 0.3959 - val_loss: 0.7256 - val_mean_absolute_error: 0.3051 - val_rmse: 0.3697 - val_smape_loss: 0.5806 - val_r2: -4.9121e-01 - val_correlation: 0.5396 - 1s/epoch - 12ms/sample
# Epoch 13/200
# 100/100 - 1s - loss: 0.7924 - mean_absolute_error: 0.3637 - rmse: 0.4693 - smape_loss: 0.6238 - r2: -1.5550e+00 - correlation: 0.3337 - val_loss: 0.4729 - val_mean_absolute_error: 0.1833 - val_rmse: 0.2399 - val_smape_loss: 0.3263 - val_r2: 0.3735 - val_correlation: 0.6370 - 1s/epoch - 11ms/sample
# Epoch 14/200
# 100/100 - 1s - loss: 0.7165 - mean_absolute_error: 0.3399 - rmse: 0.4590 - smape_loss: 0.5498 - r2: -1.4524e+00 - correlation: 0.4177 - val_loss: 0.4995 - val_mean_absolute_error: 0.1978 - val_rmse: 0.2564 - val_smape_loss: 0.3537 - val_r2: 0.2825 - val_correlation: 0.6132 - 1s/epoch - 11ms/sample
# Epoch 15/200
# 100/100 - 1s - loss: 0.6742 - mean_absolute_error: 0.3029 - rmse: 0.3946 - smape_loss: 0.5099 - r2: -7.8132e-01 - correlation: 0.4898 - val_loss: 0.5813 - val_mean_absolute_error: 0.2428 - val_rmse: 0.2986 - val_smape_loss: 0.4377 - val_r2: 0.0283 - val_correlation: 0.6753 - 1s/epoch - 11ms/sample
# Epoch 16/200
# 100/100 - 1s - loss: 0.7013 - mean_absolute_error: 0.3048 - rmse: 0.3877 - smape_loss: 0.5390 - r2: -6.8947e-01 - correlation: 0.4296 - val_loss: 0.5251 - val_mean_absolute_error: 0.2152 - val_rmse: 0.2670 - val_smape_loss: 0.3827 - val_r2: 0.2195 - val_correlation: 0.6996 - 1s/epoch - 11ms/sample
# Epoch 17/200
# 100/100 - 1s - loss: 0.6875 - mean_absolute_error: 0.2922 - rmse: 0.3810 - smape_loss: 0.5262 - r2: -6.2059e-01 - correlation: 0.4495 - val_loss: 0.5323 - val_mean_absolute_error: 0.2170 - val_rmse: 0.2714 - val_smape_loss: 0.3909 - val_r2: 0.1899 - val_correlation: 0.6682 - 1s/epoch - 11ms/sample
# Epoch 18/200
# 100/100 - 1s - loss: 0.6887 - mean_absolute_error: 0.2935 - rmse: 0.3825 - smape_loss: 0.5286 - r2: -6.0600e-01 - correlation: 0.4298 - val_loss: 0.6182 - val_mean_absolute_error: 0.2648 - val_rmse: 0.3217 - val_smape_loss: 0.4781 - val_r2: -1.2891e-01 - val_correlation: 0.6889 - 1s/epoch - 11ms/sample
# Epoch 19/200
# 100/100 - 1s - loss: 0.6587 - mean_absolute_error: 0.2698 - rmse: 0.3441 - smape_loss: 0.5005 - r2: -3.1975e-01 - correlation: 0.4643 - val_loss: 0.5771 - val_mean_absolute_error: 0.2450 - val_rmse: 0.3005 - val_smape_loss: 0.4377 - val_r2: 0.0134 - val_correlation: 0.6877 - 1s/epoch - 11ms/sample
# Epoch 20/200
# 100/100 - 1s - loss: 0.6770 - mean_absolute_error: 0.2877 - rmse: 0.3659 - smape_loss: 0.5203 - r2: -4.7996e-01 - correlation: 0.4427 - val_loss: 0.5478 - val_mean_absolute_error: 0.2307 - val_rmse: 0.2849 - val_smape_loss: 0.4091 - val_r2: 0.1171 - val_correlation: 0.6912 - 1s/epoch - 11ms/sample
# Epoch 21/200
# 100/100 - 1s - loss: 0.6062 - mean_absolute_error: 0.2564 - rmse: 0.3280 - smape_loss: 0.4510 - r2: -1.9504e-01 - correlation: 0.5087 - val_loss: 0.5638 - val_mean_absolute_error: 0.2390 - val_rmse: 0.2940 - val_smape_loss: 0.4261 - val_r2: 0.0480 - val_correlation: 0.6882 - 1s/epoch - 11ms/sample
# Epoch 22/200
# 100/100 - 1s - loss: 0.6007 - mean_absolute_error: 0.2762 - rmse: 0.3611 - smape_loss: 0.4467 - r2: -4.6342e-01 - correlation: 0.4874 - val_loss: 0.5463 - val_mean_absolute_error: 0.2296 - val_rmse: 0.2837 - val_smape_loss: 0.4092 - val_r2: 0.1180 - val_correlation: 0.6871 - 1s/epoch - 11ms/sample
# Epoch 23/200
# 100/100 - 1s - loss: 0.5961 - mean_absolute_error: 0.2590 - rmse: 0.3317 - smape_loss: 0.4451 - r2: -2.0075e-01 - correlation: 0.5087 - val_loss: 0.5208 - val_mean_absolute_error: 0.2155 - val_rmse: 0.2688 - val_smape_loss: 0.3843 - val_r2: 0.2138 - val_correlation: 0.6873 - 1s/epoch - 11ms/sample
# Epoch 24/200
# 100/100 - 1s - loss: 0.5918 - mean_absolute_error: 0.2683 - rmse: 0.3434 - smape_loss: 0.4423 - r2: -3.1632e-01 - correlation: 0.5468 - val_loss: 0.5088 - val_mean_absolute_error: 0.2089 - val_rmse: 0.2623 - val_smape_loss: 0.3730 - val_r2: 0.2478 - val_correlation: 0.6893 - 1s/epoch - 12ms/sample
# Epoch 25/200
# 100/100 - 1s - loss: 0.5560 - mean_absolute_error: 0.2386 - rmse: 0.3037 - smape_loss: 0.4082 - r2: -2.1557e-02 - correlation: 0.5583 - val_loss: 0.5410 - val_mean_absolute_error: 0.2280 - val_rmse: 0.2827 - val_smape_loss: 0.4057 - val_r2: 0.1274 - val_correlation: 0.6980 - 1s/epoch - 11ms/sample
# Epoch 26/200
# 100/100 - 1s - loss: 0.5526 - mean_absolute_error: 0.2349 - rmse: 0.3058 - smape_loss: 0.4055 - r2: -2.1549e-02 - correlation: 0.5359 - val_loss: 0.5430 - val_mean_absolute_error: 0.2306 - val_rmse: 0.2849 - val_smape_loss: 0.4081 - val_r2: 0.1149 - val_correlation: 0.6930 - 1s/epoch - 11ms/sample
# Epoch 27/200
# 100/100 - 1s - loss: 0.5601 - mean_absolute_error: 0.2458 - rmse: 0.3170 - smape_loss: 0.4136 - r2: -1.1179e-01 - correlation: 0.5499 - val_loss: 0.4773 - val_mean_absolute_error: 0.1918 - val_rmse: 0.2449 - val_smape_loss: 0.3428 - val_r2: 0.3438 - val_correlation: 0.6933 - 1s/epoch - 11ms/sample
# Epoch 28/200
# 100/100 - 1s - loss: 0.5377 - mean_absolute_error: 0.2231 - rmse: 0.2921 - smape_loss: 0.3936 - r2: 0.0571 - correlation: 0.5485 - val_loss: 0.4883 - val_mean_absolute_error: 0.1988 - val_rmse: 0.2514 - val_smape_loss: 0.3546 - val_r2: 0.3074 - val_correlation: 0.6898 - 1s/epoch - 11ms/sample
# Epoch 29/200
# 100/100 - 1s - loss: 0.5277 - mean_absolute_error: 0.2232 - rmse: 0.2914 - smape_loss: 0.3844 - r2: 0.0413 - correlation: 0.5758 - val_loss: 0.4331 - val_mean_absolute_error: 0.1648 - val_rmse: 0.2213 - val_smape_loss: 0.2995 - val_r2: 0.4649 - val_correlation: 0.6993 - 1s/epoch - 11ms/sample
# Epoch 30/200
# ...
# Epoch 154/200
# 100/100 - 1s - loss: 0.2941 - mean_absolute_error: 0.1289 - rmse: 0.1837 - smape_loss: 0.2429 - r2: 0.6276 - correlation: 0.8002 - val_loss: 0.3207 - val_mean_absolute_error: 0.1454 - val_rmse: 0.2071 - val_smape_loss: 0.2700 - val_r2: 0.5277 - val_correlation: 0.7306 - 1s/epoch - 11ms/sample
# Epoch 155/200
# 100/100 - 1s - loss: 0.3009 - mean_absolute_error: 0.1330 - rmse: 0.1892 - smape_loss: 0.2502 - r2: 0.6084 - correlation: 0.7850 - val_loss: 0.3217 - val_mean_absolute_error: 0.1467 - val_rmse: 0.2101 - val_smape_loss: 0.2715 - val_r2: 0.5176 - val_correlation: 0.7294 - 1s/epoch - 11ms/sample
# Epoch 156/200
# 100/100 - 1s - loss: 0.3011 - mean_absolute_error: 0.1340 - rmse: 0.1913 - smape_loss: 0.2507 - r2: 0.5971 - correlation: 0.7836 - val_loss: 0.3200 - val_mean_absolute_error: 0.1458 - val_rmse: 0.2072 - val_smape_loss: 0.2704 - val_r2: 0.5328 - val_correlation: 0.7338 - 1s/epoch - 11ms/sample
# Epoch 157/200
# 100/100 - 1s - loss: 0.3025 - mean_absolute_error: 0.1344 - rmse: 0.1937 - smape_loss: 0.2528 - r2: 0.5904 - correlation: 0.7762 - val_loss: 0.3204 - val_mean_absolute_error: 0.1463 - val_rmse: 0.2077 - val_smape_loss: 0.2713 - val_r2: 0.5265 - val_correlation: 0.7325 - 1s/epoch - 11ms/sample
# Epoch 158/200
# 100/100 - 1s - loss: 0.3033 - mean_absolute_error: 0.1354 - rmse: 0.1928 - smape_loss: 0.2541 - r2: 0.5884 - correlation: 0.7740 - val_loss: 0.3198 - val_mean_absolute_error: 0.1464 - val_rmse: 0.2077 - val_smape_loss: 0.2712 - val_r2: 0.5286 - val_correlation: 0.7325 - 1s/epoch - 11ms/sample
# Epoch 159/200
# 100/100 - 1s - loss: 0.3015 - mean_absolute_error: 0.1345 - rmse: 0.1918 - smape_loss: 0.2527 - r2: 0.5959 - correlation: 0.7811 - val_loss: 0.3202 - val_mean_absolute_error: 0.1469 - val_rmse: 0.2095 - val_smape_loss: 0.2720 - val_r2: 0.5187 - val_correlation: 0.7288 - 1s/epoch - 11ms/sample
# Epoch 160/200
# 100/100 - 1s - loss: 0.2942 - mean_absolute_error: 0.1310 - rmse: 0.1867 - smape_loss: 0.2459 - r2: 0.6195 - correlation: 0.7920 - val_loss: 0.3193 - val_mean_absolute_error: 0.1466 - val_rmse: 0.2090 - val_smape_loss: 0.2716 - val_r2: 0.5240 - val_correlation: 0.7288 - 1s/epoch - 11ms/sample
# Epoch 161/200
# 100/100 - 1s - loss: 0.2957 - mean_absolute_error: 0.1318 - rmse: 0.1907 - smape_loss: 0.2479 - r2: 0.6013 - correlation: 0.7823 - val_loss: 0.3193 - val_mean_absolute_error: 0.1469 - val_rmse: 0.2074 - val_smape_loss: 0.2722 - val_r2: 0.5314 - val_correlation: 0.7338 - 1s/epoch - 11ms/sample
# Epoch 162/200
# 100/100 - 1s - loss: 0.2931 - mean_absolute_error: 0.1311 - rmse: 0.1893 - smape_loss: 0.2459 - r2: 0.6055 - correlation: 0.7875 - val_loss: 0.3206 - val_mean_absolute_error: 0.1476 - val_rmse: 0.2097 - val_smape_loss: 0.2740 - val_r2: 0.5186 - val_correlation: 0.7259 - 1s/epoch - 11ms/sample
# Epoch 163/200
# 100/100 - 1s - loss: 0.2995 - mean_absolute_error: 0.1346 - rmse: 0.1922 - smape_loss: 0.2527 - r2: 0.5915 - correlation: 0.7764 - val_loss: 0.3193 - val_mean_absolute_error: 0.1475 - val_rmse: 0.2101 - val_smape_loss: 0.2729 - val_r2: 0.5150 - val_correlation: 0.7278 - 1s/epoch - 11ms/sample
# Epoch 164/200
# 100/100 - 1s - loss: 0.2936 - mean_absolute_error: 0.1313 - rmse: 0.1863 - smape_loss: 0.2470 - r2: 0.6176 - correlation: 0.7936 - val_loss: 0.3189 - val_mean_absolute_error: 0.1475 - val_rmse: 0.2109 - val_smape_loss: 0.2730 - val_r2: 0.5140 - val_correlation: 0.7247 - 1s/epoch - 11ms/sample
# Epoch 165/200
# 100/100 - 1s - loss: 0.2943 - mean_absolute_error: 0.1316 - rmse: 0.1891 - smape_loss: 0.2481 - r2: 0.6070 - correlation: 0.7866 - val_loss: 0.3174 - val_mean_absolute_error: 0.1467 - val_rmse: 0.2089 - val_smape_loss: 0.2718 - val_r2: 0.5242 - val_correlation: 0.7301 - 1s/epoch - 11ms/sample
# Epoch 166/200
# 100/100 - 1s - loss: 0.2864 - mean_absolute_error: 0.1275 - rmse: 0.1838 - smape_loss: 0.2405 - r2: 0.6213 - correlation: 0.7973 - val_loss: 0.3183 - val_mean_absolute_error: 0.1476 - val_rmse: 0.2101 - val_smape_loss: 0.2731 - val_r2: 0.5178 - val_correlation: 0.7268 - 1s/epoch - 11ms/sample
# Epoch 167/200
# 100/100 - 1s - loss: 0.2931 - mean_absolute_error: 0.1316 - rmse: 0.1896 - smape_loss: 0.2479 - r2: 0.6076 - correlation: 0.7860 - val_loss: 0.3169 - val_mean_absolute_error: 0.1469 - val_rmse: 0.2101 - val_smape_loss: 0.2723 - val_r2: 0.5154 - val_correlation: 0.7250 - 1s/epoch - 11ms/sample
# Epoch 168/200
# 100/100 - 1s - loss: 0.2843 - mean_absolute_error: 0.1273 - rmse: 0.1829 - smape_loss: 0.2395 - r2: 0.6298 - correlation: 0.8018 - val_loss: 0.3164 - val_mean_absolute_error: 0.1469 - val_rmse: 0.2095 - val_smape_loss: 0.2723 - val_r2: 0.5180 - val_correlation: 0.7285 - 1s/epoch - 12ms/sample
# Epoch 169/200
# 100/100 - 1s - loss: 0.2860 - mean_absolute_error: 0.1283 - rmse: 0.1846 - smape_loss: 0.2417 - r2: 0.6218 - correlation: 0.7974 - val_loss: 0.3165 - val_mean_absolute_error: 0.1471 - val_rmse: 0.2072 - val_smape_loss: 0.2727 - val_r2: 0.5321 - val_correlation: 0.7330 - 1s/epoch - 11ms/sample
# Epoch 170/200
# 100/100 - 1s - loss: 0.2892 - mean_absolute_error: 0.1301 - rmse: 0.1872 - smape_loss: 0.2453 - r2: 0.6075 - correlation: 0.7871 - val_loss: 0.3167 - val_mean_absolute_error: 0.1477 - val_rmse: 0.2113 - val_smape_loss: 0.2734 - val_r2: 0.5118 - val_correlation: 0.7260 - 1s/epoch - 11ms/sample
# Epoch 171/200
# 100/100 - 1s - loss: 0.2919 - mean_absolute_error: 0.1323 - rmse: 0.1908 - smape_loss: 0.2485 - r2: 0.5993 - correlation: 0.7829 - val_loss: 0.3162 - val_mean_absolute_error: 0.1475 - val_rmse: 0.2095 - val_smape_loss: 0.2734 - val_r2: 0.5204 - val_correlation: 0.7275 - 1s/epoch - 11ms/sample
# Epoch 172/200
# 100/100 - 1s - loss: 0.2891 - mean_absolute_error: 0.1310 - rmse: 0.1857 - smape_loss: 0.2463 - r2: 0.6199 - correlation: 0.7943 - val_loss: 0.3151 - val_mean_absolute_error: 0.1473 - val_rmse: 0.2105 - val_smape_loss: 0.2727 - val_r2: 0.5167 - val_correlation: 0.7295 - 1s/epoch - 11ms/sample
# Epoch 173/200
# 100/100 - 1s - loss: 0.2952 - mean_absolute_error: 0.1343 - rmse: 0.1925 - smape_loss: 0.2526 - r2: 0.5959 - correlation: 0.7828 - val_loss: 0.3143 - val_mean_absolute_error: 0.1470 - val_rmse: 0.2078 - val_smape_loss: 0.2722 - val_r2: 0.5287 - val_correlation: 0.7327 - 1s/epoch - 11ms/sample
# Epoch 174/200
# 100/100 - 1s - loss: 0.2862 - mean_absolute_error: 0.1298 - rmse: 0.1883 - smape_loss: 0.2439 - r2: 0.6006 - correlation: 0.7820 - val_loss: 0.3132 - val_mean_absolute_error: 0.1465 - val_rmse: 0.2076 - val_smape_loss: 0.2715 - val_r2: 0.5230 - val_correlation: 0.7289 - 1s/epoch - 11ms/sample
# Epoch 175/200
# 100/100 - 1s - loss: 0.2773 - mean_absolute_error: 0.1248 - rmse: 0.1799 - smape_loss: 0.2355 - r2: 0.6422 - correlation: 0.8072 - val_loss: 0.3139 - val_mean_absolute_error: 0.1473 - val_rmse: 0.2111 - val_smape_loss: 0.2727 - val_r2: 0.5131 - val_correlation: 0.7262 - 1s/epoch - 11ms/sample
# Epoch 176/200
# 100/100 - 1s - loss: 0.2876 - mean_absolute_error: 0.1313 - rmse: 0.1892 - smape_loss: 0.2462 - r2: 0.6035 - correlation: 0.7847 - val_loss: 0.3135 - val_mean_absolute_error: 0.1473 - val_rmse: 0.2106 - val_smape_loss: 0.2727 - val_r2: 0.5129 - val_correlation: 0.7268 - 1s/epoch - 11ms/sample
# Epoch 177/200
# 100/100 - 1s - loss: 0.2805 - mean_absolute_error: 0.1274 - rmse: 0.1803 - smape_loss: 0.2396 - r2: 0.6324 - correlation: 0.8010 - val_loss: 0.3143 - val_mean_absolute_error: 0.1480 - val_rmse: 0.2114 - val_smape_loss: 0.2740 - val_r2: 0.5092 - val_correlation: 0.7228 - 1s/epoch - 11ms/sample
# Epoch 178/200
# 100/100 - 1s - loss: 0.2806 - mean_absolute_error: 0.1278 - rmse: 0.1841 - smape_loss: 0.2400 - r2: 0.6277 - correlation: 0.7999 - val_loss: 0.3122 - val_mean_absolute_error: 0.1470 - val_rmse: 0.2096 - val_smape_loss: 0.2722 - val_r2: 0.5167 - val_correlation: 0.7271 - 1s/epoch - 11ms/sample
# Epoch 179/200
# 100/100 - 1s - loss: 0.2892 - mean_absolute_error: 0.1322 - rmse: 0.1863 - smape_loss: 0.2491 - r2: 0.6174 - correlation: 0.7937 - val_loss: 0.3132 - val_mean_absolute_error: 0.1479 - val_rmse: 0.2109 - val_smape_loss: 0.2736 - val_r2: 0.5147 - val_correlation: 0.7245 - 1s/epoch - 11ms/sample
# Epoch 180/200
# 100/100 - 1s - loss: 0.2804 - mean_absolute_error: 0.1277 - rmse: 0.1856 - smape_loss: 0.2408 - r2: 0.6164 - correlation: 0.7911 - val_loss: 0.3120 - val_mean_absolute_error: 0.1474 - val_rmse: 0.2099 - val_smape_loss: 0.2728 - val_r2: 0.5186 - val_correlation: 0.7271 - 1s/epoch - 11ms/sample
# Epoch 181/200
# 100/100 - 1s - loss: 0.2896 - mean_absolute_error: 0.1328 - rmse: 0.1908 - smape_loss: 0.2503 - r2: 0.6015 - correlation: 0.7819 - val_loss: 0.3111 - val_mean_absolute_error: 0.1469 - val_rmse: 0.2081 - val_smape_loss: 0.2723 - val_r2: 0.5277 - val_correlation: 0.7318 - 1s/epoch - 11ms/sample
# Epoch 182/200
# 100/100 - 1s - loss: 0.2781 - mean_absolute_error: 0.1273 - rmse: 0.1865 - smape_loss: 0.2392 - r2: 0.6020 - correlation: 0.7905 - val_loss: 0.3119 - val_mean_absolute_error: 0.1479 - val_rmse: 0.2108 - val_smape_loss: 0.2735 - val_r2: 0.5148 - val_correlation: 0.7263 - 1s/epoch - 11ms/sample
# Epoch 183/200
# 100/100 - 1s - loss: 0.2881 - mean_absolute_error: 0.1327 - rmse: 0.1897 - smape_loss: 0.2495 - r2: 0.6016 - correlation: 0.7840 - val_loss: 0.3102 - val_mean_absolute_error: 0.1468 - val_rmse: 0.2089 - val_smape_loss: 0.2721 - val_r2: 0.5207 - val_correlation: 0.7306 - 1s/epoch - 11ms/sample
# Epoch 184/200
# 100/100 - 1s - loss: 0.2734 - mean_absolute_error: 0.1246 - rmse: 0.1788 - smape_loss: 0.2353 - r2: 0.6465 - correlation: 0.8089 - val_loss: 0.3108 - val_mean_absolute_error: 0.1474 - val_rmse: 0.2109 - val_smape_loss: 0.2732 - val_r2: 0.5152 - val_correlation: 0.7267 - 1s/epoch - 11ms/sample
# Epoch 185/200
# 100/100 - 1s - loss: 0.2743 - mean_absolute_error: 0.1252 - rmse: 0.1787 - smape_loss: 0.2366 - r2: 0.6493 - correlation: 0.8102 - val_loss: 0.3123 - val_mean_absolute_error: 0.1486 - val_rmse: 0.2106 - val_smape_loss: 0.2750 - val_r2: 0.5099 - val_correlation: 0.7233 - 1s/epoch - 11ms/sample
# Epoch 186/200
# 100/100 - 1s - loss: 0.2791 - mean_absolute_error: 0.1283 - rmse: 0.1834 - smape_loss: 0.2417 - r2: 0.6273 - correlation: 0.8005 - val_loss: 0.3108 - val_mean_absolute_error: 0.1478 - val_rmse: 0.2098 - val_smape_loss: 0.2738 - val_r2: 0.5214 - val_correlation: 0.7286 - 1s/epoch - 11ms/sample
# Epoch 187/200
# 100/100 - 1s - loss: 0.2754 - mean_absolute_error: 0.1268 - rmse: 0.1819 - smape_loss: 0.2384 - r2: 0.6360 - correlation: 0.8052 - val_loss: 0.3127 - val_mean_absolute_error: 0.1494 - val_rmse: 0.2136 - val_smape_loss: 0.2761 - val_r2: 0.4979 - val_correlation: 0.7181 - 1s/epoch - 11ms/sample
# Epoch 188/200
# 100/100 - 1s - loss: 0.2792 - mean_absolute_error: 0.1290 - rmse: 0.1882 - smape_loss: 0.2425 - r2: 0.6083 - correlation: 0.7869 - val_loss: 0.3123 - val_mean_absolute_error: 0.1492 - val_rmse: 0.2129 - val_smape_loss: 0.2760 - val_r2: 0.5056 - val_correlation: 0.7237 - 1s/epoch - 11ms/sample
# Epoch 189/200
# 100/100 - 1s - loss: 0.2874 - mean_absolute_error: 0.1337 - rmse: 0.1916 - smape_loss: 0.2511 - r2: 0.5961 - correlation: 0.7831 - val_loss: 0.3097 - val_mean_absolute_error: 0.1478 - val_rmse: 0.2114 - val_smape_loss: 0.2738 - val_r2: 0.5119 - val_correlation: 0.7250 - 1s/epoch - 11ms/sample
# Epoch 190/200
# 100/100 - 1s - loss: 0.2800 - mean_absolute_error: 0.1298 - rmse: 0.1897 - smape_loss: 0.2443 - r2: 0.6033 - correlation: 0.7848 - val_loss: 0.3114 - val_mean_absolute_error: 0.1493 - val_rmse: 0.2110 - val_smape_loss: 0.2759 - val_r2: 0.5118 - val_correlation: 0.7301 - 1s/epoch - 11ms/sample
# Epoch 191/200
# 100/100 - 1s - loss: 0.2803 - mean_absolute_error: 0.1304 - rmse: 0.1892 - smape_loss: 0.2449 - r2: 0.6033 - correlation: 0.7891 - val_loss: 0.3077 - val_mean_absolute_error: 0.1471 - val_rmse: 0.2092 - val_smape_loss: 0.2725 - val_r2: 0.5231 - val_correlation: 0.7322 - 1s/epoch - 11ms/sample
# Epoch 192/200
# 100/100 - 1s - loss: 0.2811 - mean_absolute_error: 0.1306 - rmse: 0.1885 - smape_loss: 0.2457 - r2: 0.6077 - correlation: 0.7882 - val_loss: 0.3077 - val_mean_absolute_error: 0.1473 - val_rmse: 0.2094 - val_smape_loss: 0.2725 - val_r2: 0.5226 - val_correlation: 0.7310 - 1s/epoch - 11ms/sample
# Epoch 193/200
# 100/100 - 1s - loss: 0.2735 - mean_absolute_error: 0.1262 - rmse: 0.1790 - smape_loss: 0.2382 - r2: 0.6471 - correlation: 0.8097 - val_loss: 0.3078 - val_mean_absolute_error: 0.1475 - val_rmse: 0.2104 - val_smape_loss: 0.2730 - val_r2: 0.5119 - val_correlation: 0.7304 - 1s/epoch - 11ms/sample
# Epoch 194/200
# 100/100 - 1s - loss: 0.2788 - mean_absolute_error: 0.1301 - rmse: 0.1866 - smape_loss: 0.2439 - r2: 0.6137 - correlation: 0.7969 - val_loss: 0.3084 - val_mean_absolute_error: 0.1480 - val_rmse: 0.2108 - val_smape_loss: 0.2739 - val_r2: 0.5149 - val_correlation: 0.7276 - 1s/epoch - 11ms/sample
# Epoch 195/200
# 100/100 - 1s - loss: 0.2760 - mean_absolute_error: 0.1279 - rmse: 0.1877 - smape_loss: 0.2414 - r2: 0.6118 - correlation: 0.7881 - val_loss: 0.3073 - val_mean_absolute_error: 0.1474 - val_rmse: 0.2096 - val_smape_loss: 0.2731 - val_r2: 0.5192 - val_correlation: 0.7284 - 1s/epoch - 11ms/sample
# Epoch 196/200
# 100/100 - 1s - loss: 0.2833 - mean_absolute_error: 0.1324 - rmse: 0.1907 - smape_loss: 0.2490 - r2: 0.5966 - correlation: 0.7817 - val_loss: 0.3072 - val_mean_absolute_error: 0.1476 - val_rmse: 0.2097 - val_smape_loss: 0.2734 - val_r2: 0.5186 - val_correlation: 0.7311 - 1s/epoch - 11ms/sample
# Epoch 197/200
# 100/100 - 1s - loss: 0.2802 - mean_absolute_error: 0.1312 - rmse: 0.1913 - smape_loss: 0.2465 - r2: 0.5910 - correlation: 0.7776 - val_loss: 0.3069 - val_mean_absolute_error: 0.1477 - val_rmse: 0.2108 - val_smape_loss: 0.2734 - val_r2: 0.5142 - val_correlation: 0.7256 - 1s/epoch - 11ms/sample
# Epoch 198/200
# 100/100 - 1s - loss: 0.2810 - mean_absolute_error: 0.1315 - rmse: 0.1875 - smape_loss: 0.2475 - r2: 0.6107 - correlation: 0.7905 - val_loss: 0.3068 - val_mean_absolute_error: 0.1479 - val_rmse: 0.2108 - val_smape_loss: 0.2737 - val_r2: 0.5158 - val_correlation: 0.7289 - 1s/epoch - 11ms/sample
# Epoch 199/200
# 100/100 - 1s - loss: 0.2762 - mean_absolute_error: 0.1288 - rmse: 0.1860 - smape_loss: 0.2430 - r2: 0.6113 - correlation: 0.7877 - val_loss: 0.3047 - val_mean_absolute_error: 0.1466 - val_rmse: 0.2087 - val_smape_loss: 0.2720 - val_r2: 0.5251 - val_correlation: 0.7309 - 1s/epoch - 11ms/sample
# Epoch 200/200
# 100/100 - 1s - loss: 0.2745 - mean_absolute_error: 0.1285 - rmse: 0.1873 - smape_loss: 0.2418 - r2: 0.6107 - correlation: 0.7906 - val_loss: 0.3056 - val_mean_absolute_error: 0.1477 - val_rmse: 0.2113 - val_smape_loss: 0.2733 - val_r2: 0.5116 - val_correlation: 0.7267 - 1s/epoch - 11ms/sample
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# *******Test*******
# *****oil*****
# smape: 3.254
# correlation: 0.972
# r2 0.944
# *****water*****
# smape: 18.686
# correlation: 0.958
# r2 0.916
# *****gas*****
# smape: 3.281
# correlation: 0.972
# r2 0.945
# *****bhp*****
# smape: 0.749
# correlation: 0.883
# r2 0.769
# *******Validation*******
# *****oil*****
# smape: 3.535
# correlation: 0.965
# r2 0.93
# *****water*****
# smape: 18.775
# correlation: 0.949
# r2 0.898
# *****gas*****
# smape: 3.606
# correlation: 0.965
# r2 0.93
# *****bhp*****
# smape: 0.803
# correlation: 0.852
# r2 0.726
# 0 oilO
# O
# 35 waterW
# W
# 70 gasG
# G
# 105 bhpB
# B
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# (60, 1094)
# Sensitivity Analysis - Sampler
# (1122304, 1094)
# Metrics: [0.1352913, 0.17994842, 0.251907, 0.60938585, 0.7922294]
# /usr/local/lib/python3.8/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
from SALib.analyze import sobol as sobol_analyze
import multiprocessing

def perform_sensitivity_analysis(position):
    # Select the desired positions for all rows
    selected_outputs = y_test_sobol[:, position].reshape(-1, 1)
    selected_outputs = np.ravel(selected_outputs)

    # Perform sensitivity analysis using the Sobol' method
    sobol_indices = sobol_analyze.analyze(problem, selected_outputs, calc_second_order=False)

    # Get the first-order and total sensitivity indices
    first_order_indices = sobol_indices['S1']
    total_indices = sobol_indices['ST']

    # Return the indices
    return first_order_indices, total_indices

def perform_parallel_sensitivity_analysis(positions):
    """
    Executes sensitivity analysis in parallel across a range of positions.

    Utilizes all available CPU cores to perform sensitivity analysis for each position
    in the specified range, using a provided sensitivity analysis function.

    Parameters:
    - positions (range): A range of positions for which to perform sensitivity analysis.

    Returns:
    - all_feature_indices (tuple): A tuple containing the first-order sensitivity indices
      for all analyzed positions.
    - all_total_indices (tuple): A tuple containing the total sensitivity indices for
      all analyzed positions.

    """
    with multiprocessing.Pool() as pool:
        results = pool.map(perform_sensitivity_analysis, positions)
    
    all_feature_indices, all_total_indices = zip(*results)
    return all_feature_indices, all_total_indices



position_oleo = range(0, 35)
position_agua = range(35, 70)
position_gas = range(70, 105)
position_bhp = range(105, 140)

# Execute the parallel sensitivity analysis
all_feature_indices, all_total_indices = perform_parallel_sensitivity_analysis(position_oleo)

# Calculate mean indices
mean_feature_indices = np.mean(all_feature_indices, axis=0)
mean_total_indices = np.mean(all_total_indices, axis=0)

# %%
import matplotlib.pyplot as plt
def visualize_average_feature_contributions(mean_feature_indices, filenames):
    """
    Visualizes the average contribution of feature groups based on Sabol first-order indices.

    Parameters:
    - mean_feature_indices (array-like): Array containing mean first-order sensitivity indices.
    - filenames (list of str): Names representing each feature group for labeling purposes.

    The function groups indices into predefined segments, sums their contributions, and
    visualizes these contributions using a bar chart with custom colors for each group.
    """
    groups = aggregate_feature_groups(mean_feature_indices)
    
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(figsize=(17, 7))
        fig.set_facecolor("w")
        ax.set_facecolor("white")
        bar_colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'cyan', 'magenta', 'lime', 'brown']
        ax.bar(filenames, groups, color=bar_colors)
        plt.xticks(fontsize=30)  # Set the fontsize

        ax.set_xlabel('Feature Group', fontsize=30)
        ax.set_ylabel('First-order Index', fontsize=30)
        ax.set_title('Average Feature Contribution - Sobol First-order', fontsize=32)
        ax.legend(title='')
        plt.grid(visible=0)
        plt.show()

def aggregate_feature_groups(mean_feature_indices):
    """
    Aggregates mean feature indices into predefined groups, summing their contributions.

    Parameters:
    - mean_feature_indices (array-like): Array containing mean first-order sensitivity indices.

    Returns:
    - groups (list): List of summed contributions for each predefined feature group.
    """
    groups = []
    # Aggregate contributions for the first 512 indices
    for i in range(0, 1024, 256):
        group_importances = sum(mean_feature_indices[i:i+256])
        groups.append(group_importances)
    
    # Aggregate contributions for the next set of indices
    for i in range(1024, 1094, 70):
        group_importances = sum(mean_feature_indices[i:i+70])
        groups.append(group_importances)
    
    return groups


filenames = ["Por", "Rtp", "Ntg", "Perm", "Uncertanty"]
visualize_average_feature_contributions(mean_feature_indices, filenames)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def visualize_average_total_contributions(mean_total_indices, filenames):
    """
    Visualizes the average contribution of feature groups based on Sabol total indices.

    Parameters:
    - mean_total_indices (array-like): Array containing mean total sensitivity indices for features.
    - filenames (list of str): Labels for each feature group, used for the x-axis in the plot.

    This function aggregates total indices into predefined groups and visualizes these
    contributions using a bar chart, applying custom colors to each feature group.
    """
    groups = aggregate_total_groups(mean_total_indices)
    
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(figsize=(17, 7))
        fig.set_facecolor("w")
        ax.set_facecolor("white")
        bar_colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'cyan', 'magenta', 'lime', 'brown']
        ax.bar(filenames, groups, color=bar_colors)
        plt.xticks(fontsize=30)
        ax.set_xlabel('Feature Group', fontsize=30)
        ax.set_ylabel('Total Index', fontsize=30)
        ax.set_title('Average Feature Contribution - Sobol Total Index', fontsize=32)
        ax.legend(title='')
        plt.grid(visible=0)
        plt.show()

def aggregate_total_groups(mean_total_indices):
    """
    Aggregates mean total indices into predefined groups, calculating their summed contributions.

    Parameters:
    - mean_total_indices (array-like): Array of mean total sensitivity indices.

    Returns:
    - groups (list): Summed contributions for each predefined feature group.
    """
    groups = []
    # Aggregate for the first set of indices
    for i in range(0, 1024, 256):
        group_importances = sum(mean_feature_indices[i:i+256])
        groups.append(group_importances)
    
    # Aggregate contributions for the next set of indices
    for i in range(1024, 1094, 70):
        group_importances = sum(mean_feature_indices[i:i+70])
        groups.append(group_importances)
    
    return groups

visualize_average_total_contributions(mean_total_indices, filenames)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
